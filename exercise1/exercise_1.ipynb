# %%
import numpy as np
import _pickle as cPickle
import os
import gzip

# %% [markdown]
# # First exercise: Classifying MNIST with MLPs
# In this exercise you will implement a Neural Network (or MLP) and classify the MNIST digits with it.
# MNIST is a "well hung" dataset that has been used a lot over the years to benchmark different classification algorithms.
# To learn more about it have a look here: http://yann.lecun.com/exdb/mnist/ .

# %% [markdown]
# # Data Loading
# We first define a function for downloading and loading MNIST.
# **WARNING**: Executing it will obviously use up some space on your machine ;).

# %%
def mnist(datasets_dir='./data'):
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'mnist.pkl.gz')
    if not os.path.exists(data_file):
        print('... downloading MNIST from the web')
        try:
            import urllib
            urllib.urlretrieve('http://google.com')
        except AttributeError:
            import urllib.request as urllib
        url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
        urllib.urlretrieve(url, data_file)

    print('... loading data')
    # Load the dataset
    f = gzip.open(data_file, 'rb')
    try:
        train_set, valid_set, test_set = cPickle.load(f, encoding="latin1")
    except TypeError:
        train_set, valid_set, test_set = cPickle.load(f)
    f.close()

    test_x, test_y = test_set
    test_x = test_x.astype('float32')
    test_x = test_x.astype('float32').reshape(test_x.shape[0], 1, 28, 28)
    test_y = test_y.astype('int32')
    valid_x, valid_y = valid_set
    valid_x = valid_x.astype('float32')
    valid_x = valid_x.astype('float32').reshape(valid_x.shape[0], 1, 28, 28)
    valid_y = valid_y.astype('int32')
    train_x, train_y = train_set
    train_x = train_x.astype('float32').reshape(train_x.shape[0], 1, 28, 28)
    train_y = train_y.astype('int32')
    rval = [(train_x, train_y), (valid_x, valid_y), (test_x, test_y)]
    print('... done loading data')
    return rval

# %% [markdown]
# # Neural Network Layers
# We now define "bare bone" neural network layers.
# The parts marked with **TODO** are where you should finish the implementation!
# Conceptually we will implement the layers as follows:
#
# Each layer has a constructor that takes an input layer plus some additional arguments such as layer size and the activation function name. The layer then uses the provided input layer to compute the layer dimensions, weight shapes, etc. and setup all auxilliary variables.
#
# Each layer then has to provide three functions (as defined in the Layer class below): *output_shape()*, *fprop()* and *brop()*. The output_shape function is used to figure out the shape for the next layer and the *fprop()/bprop()* functions are used to compute forward and backward passes through the network.

# %%
# start by defining simple helpers
def sigmoid(x):
    return 1.0/(1.0+np.exp(-x))

def sigmoid_d(x):
    return sigmoid(x)*(1-sigmoid(x))

def tanh(x):
    return np.tanh(x)

def tanh_d(x):
    return 1-tanh(x)**2

def relu(x):
    return np.maximum(0.0, x)

def relu_d(x):
    return (x > 0).astype(float)

def softmax(x, axis=1):
    # to make the softmax a "safe" operation we will 
    # first subtract the maximum along the specified axis
    # so that np.exp(x) does not blow up!
    # Note that this does not change the output.
    x_max = np.max(x, axis=axis, keepdims=True)
    x_safe = x - x_max
    e_x = np.exp(x_safe)
    return e_x / np.sum(e_x, axis=axis, keepdims=True)

def one_hot(labels):
    """this creates a one hot encoding from a flat vector:
    i.e. given y = [0,2,1]
     it creates y_one_hot = [[1,0,0], [0,0,1], [0,1,0]]
    """
    classes = np.unique(labels)
    n_classes = classes.size
    one_hot_labels = np.zeros(labels.shape + (n_classes,))
    for c in classes:
        one_hot_labels[labels == c, c] = 1
    return one_hot_labels

def unhot(one_hot_labels):
    """ Invert a one hot encoding, creating a flat vector """
    return np.argmax(one_hot_labels, axis=-1)

# then define an activation function class
class Activation(object):
    
    def __init__(self, tname):
        if tname == 'sigmoid':
            self.act = sigmoid
            self.act_d = sigmoid_d
        elif tname == 'tanh':
            self.act = tanh
            self.act_d = tanh_d
        elif tname == 'relu':
            self.act = relu
            self.act_d = relu_d
        else:
            raise ValueError('Invalid activation function.')
            
    def fprop(self, input):
        # we need to remember the last input
        # so that we can calculate the derivative with respect
        # to it later on
        self.last_input = input
        return self.act(input)
    
    def bprop(self, output_grad):
        return output_grad * self.act_d(self.last_input)

# define a base class for layers
class Layer(object):
    
    def fprop(self, input):
        """ Calculate layer output for given input 
            (forward propagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def bprop(self, output_grad):
        """ Calculate input gradient and gradient 
            with respect to weights and bias (backpropagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def output_size(self):
        """ Calculate size of this layer's output.
        input_shape[0] is the number of samples in the input.
        input_shape[1:] is the shape of the feature.
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for loss outputs
# an output layer can then simply be derived
# from both Layer and Loss 
class Loss(object):

    def loss(self, output, output_net):
        """ Calculate mean loss given real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def input_grad(self, output, output_net):
        """ Calculate input gradient real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for parameterized things        
class Parameterized(object):
    
    def params(self):
        """ Return parameters (by reference) """
        raise NotImplementedError('This is an interface class, please use a derived instance')
    
    def grad_params(self):
        """ Return accumulated gradient with respect to params. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a container for providing input to the network
class InputLayer(Layer):
    
    def __init__(self, input_shape):
        if not isinstance(input_shape, tuple):
            raise ValueError("InputLayer requires input_shape as a tuple")
        self.input_shape = input_shape

    def output_size(self):
        return self.input_shape
    
    def fprop(self, input):
        return input
    
    def bprop(self, output_grad):
        return output_grad
        
class FullyConnectedLayer(Layer, Parameterized):
    """ A standard fully connected hidden layer, as discussed in the lecture.
    """
    
    def __init__(self, input_layer, num_units, 
                 init_stddev, activation_fun=Activation('relu')):
        self.num_units = num_units
        self.activation_fun = activation_fun
        # the input shape will be of size (batch_size, num_units_prev) 
        # where num_units_prev is the number of units in the input 
        # (previous) layer
        self.input_shape = input_layer.output_size()
        # TODO ################################
        # TODO: implement weight initialization
        # TODO ################################
        # this is the weight matrix it should have shape: (num_units_prev, num_units)
        self.W = np.random.normal(0, init_stddev, (self.input_shape[1], num_units))  #FIXME
        # and this is the bias vector of shape: (num_units)
        self.b = np.random.normal(0, init_stddev, (num_units)) #FIXME
        # create dummy variables for parameter gradients
        # no need to change these here!
        self.dW = None
        self.db = None
    
    def output_size(self):
        return (self.input_shape[0], self.num_units)
    
    def fprop(self, input):
        # TODO ################################################
        # TODO: implement forward propagation
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        #       then this is simply a linear layer
        # TODO ################################################
        # you again want to cache the last_input for the bprop
        # implementation below!
        self.last_input = input
        # NOTE: Use numpy dot product
        # h = t(a), a = W * x + b 
        
        #FIXME
        a = input.dot(self.W) + self.b
        if self.activation_fun is None:
            return a
        else:
            return self.activation_fun.fprop(a)
        
    def bprop(self, output_grad):
        """ Calculate input gradient (backpropagation). """
        # TODO ################################
        # TODO: implement backward propagation
        # TODO ###############################
        
        # HINT: you may have to divide dW and db by n
        #       to make gradient checking work 
        #       OR you divide the gradient in the output layer by n
        n = output_grad.shape[0]
        # accumulate gradient wrt. the parameters first
        # we will need to store these to later update
        # the network after a few forward backward passes
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        # the gradient wrt. W should be stored as self.dW
        # the gradient wrt. b should be stored as self.db
        
        # NOTE: self.dW is also a numpy dot product
        if self.activation_fun is None:
            dZ = output_grad
        else:
            dZ = self.activation_fun.bprop(output_grad)
        self.dW = self.last_input.T.dot(dZ)/n #FIXME
        eye = np.eye(n)
        self.db = np.sum(eye.dot(dZ)/n, axis=0) #FIXME
        # the gradient wrt. the input should be calculated here
        grad_input = dZ.dot(self.W.T)
        return grad_input
        
    def params(self):
        return self.W, self.b

    def grad_params(self):
        return self.dW, self.db

# finally we specify the interface for output layers 
# which are layers that also have a loss function
# we will implement two output layers:
#  a Linear, and Softmax (Logistic Regression) layer
# The difference between output layers and and normal 
# layers is that they will be called to compute the gradient
# of the loss through input_grad(). bprop will never 
# be called on them!
class LinearOutput(Layer, Loss):
    """ A simple linear output layer that  
        uses a squared loss (e.g. should be used for regression)
    """
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
        
    def fprop(self, input):
        return input

    def bprop(self, output_grad):
        raise NotImplementedError(
            'LinearOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # TODO ####################################
        # TODO: implement gradient of squared loss
        # TODO ####################################
        return Y_pred - Y

    def loss(self, Y, Y_pred):
        loss = 0.5 * np.square(Y_pred - Y)
        return np.mean(np.sum(loss, axis=1))

class SoftmaxOutput(Layer, Loss):
    """ A softmax output layer that calculates 
        the negative log likelihood as loss
        and should be used for classification.
    """
    
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
    
    def fprop(self, input):
        return softmax(input)
    
    def bprop(self, output_grad):
        raise NotImplementedError(
            'SoftmaxOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # TODO #######################################################
        # TODO: implement gradient of the negative log likelihood loss
        # TODO #######################################################
        # HINT: since this would involve taking the log 
        #       of the softmax (which is np.exp(x)/np.sum(x, axis=1))
        #       this gradient computation can be simplified a lot,
        #       you may find a connection to the LinearOutput layer!
        return -(Y-Y_pred)

    def loss(self, Y, Y_pred):
        # Assume one-hot encoding of Y
        out = Y_pred
        # to make the loss numerically stable 
        # you should add an epsilon in the log ;)
        eps = 1e-10
        # TODO ####################################
        # calculate negative log likelihood
        # TODO ####################################
        loss = np.sum(-np.log(out + eps) * Y, axis=1)
        return np.mean(loss)

# %% [markdown]
# # Neural Network class
# With all layers in place (and properly implemented by you) we can finally define a neural network.
# For our purposes a neural network is simply a collection of layers which we will cycle through and on which we will call fprop and bprop to compute partial derivatives with respect to the input and the parameters.
#
# Pay special attention to the *check_gradients()* function in which you should implement automatic differentiation. This function will become your best friend when checking the correctness of your implementation.

# %%
import random
import matplotlib.pyplot as plt

class NeuralNetwork:
    """ Our Neural Network container class.
    """
    def __init__(self, layers):
        self.layers = layers
        self.loss_prev = np.inf
        
    def _loss(self, X, Y):
        Y_pred = self.predict(X)
        return self.layers[-1].loss(Y, Y_pred)

    def predict(self, X):
        """ Calculate an output Y for the given input X. """
        # TODO ##########################################
        # TODO: implement forward pass through all layers
        # TODO ##########################################
        Y_pred = self.layers[0].fprop(X)
        for l in self.layers[1:]:
            Y_pred = l.fprop(Y_pred)
        return Y_pred
    
    def backpropagate(self, Y, Y_pred, upto=0):
        """ Backpropagation of partial derivatives through 
            the complete network up to layer 'upto'
        """
        next_grad = self.layers[-1].input_grad(Y, Y_pred)
        # TODO ##########################################
        # TODO: implement backward pass through all layers
        # TODO ##########################################
        for l in self.layers[-2:upto - len(self.layers) - 1:-1]:
            next_grad = l.bprop(next_grad)
    
    def classification_error(self, X, Y):
        """ Calculate error on the given data 
            assuming they are classes that should be predicted. 
        """
        Y_pred = unhot(self.predict(X))
        error = Y_pred != Y
        return np.mean(error)
    
    def sgd_epoch(self, X, Y, learning_rate, batch_size):
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        for b in range(n_batches):
            # TODO #####################################
            # Implement stochastic gradient descent here
            # TODO #####################################
            # start by extracting a batch from X and Y
            # (you can assume the inputs are already shuffled)
            samples = random.sample(range(n_samples), batch_size)
            X_sampled = X[samples]
            Y_sampled = Y[samples]
            # TODO: then forward and backward propagation + updates
            # HINT: layer.params() returns parameters *by reference*
            #       so you can easily update in-place
            Y_pred_sampled = self.predict(X_sampled)
            for l, layer in enumerate(self.layers[1:-2], start=1):
                self.backpropagate(Y_sampled, Y_pred_sampled, upto=l)
                W, b = layer.params() 
                dW, db = layer.grad_params()
                W -= learning_rate * dW
                b -= learning_rate * db
                
    
    def gd_epoch(self, X, Y, learning_rate):
        n_samples = X.shape[0]
        batch_size = 100
        n_batches = n_samples//batch_size
        # TODO ##################################################
        # Implement batch gradient descent here
        # A few hints:
        #   There are two strategies you can follow:
        #   Either shove the whole dataset throught the network
        #   at once (which can be problematic for large datasets)
        #   or run through it batch wise as in the sgd approach
        #   and accumulate the gradients for all parameters as
        #   you go through the data. Either way you should then
        #   do one gradient step after you went through the
        #   complete dataset!
        # TODO ##################################################
        X_batches = [X[batch_size*i:batch_size*(i+1)] for i in range(n_batches)]
        Y_batches = [Y[batch_size*i:batch_size*(i+1)] for i in range(n_batches)]
        gradients = {}
        for b in range(n_batches):
            X_batch = X_batches[b]
            Y_batch = Y_batches[b]
            Y_pred_batch = self.predict(X_batch)
            for l, layer in enumerate(self.layers[1:-2], start=1):
                self.backpropagate(Y_batch, Y_pred_batch, upto=l)
                dW, db = layer.grad_params()
                if l not in gradients:
                    gradients[l] = {'dW':dW, 'db':db}
                else:
                    gradients[l]['dW'] += dW
                    gradients[l]['db'] += db
        
        for l, layer in enumerate(self.layers[1:-2], start=1):
            W, b = layer.params()
            W -= learning_rate * gradients[l]['dW']
            b -= learning_rate * gradients[l]['db']
    
    def train(self, X, Y, X_valid, Y_valid, learning_rate=0.1, max_epochs=100, batch_size=64,
              descent_type="sgd", y_one_hot=True):
        """ Train network on the given data. """
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        eps = 1e-10
        
        if y_one_hot:
            Y_train = one_hot(Y)
            Y_valid_hot = one_hot(Y_valid)
        else:
            Y_train = Y
        
        print("... starting training")
        #lists to collect errors on data
        epochs = range(max_epochs+1)
        train_accuracy_plot = []
        train_loss_plot = []
        valid_accuracy_plot = []
        valid_loss_plot = []
        for e in range(max_epochs+1):
            if descent_type == "sgd":
                self.sgd_epoch(X, Y_train, learning_rate, batch_size)
            elif descent_type == "gd":
                self.gd_epoch(X, Y_train, learning_rate)
            else:
                raise NotImplementedError("Unknown gradient descent type {}".format(descent_type))

            # Output error on the training data
            train_loss = self._loss(X, Y_train)
            train_loss_plot.append(train_loss)
            train_error = self.classification_error(X, Y)
            train_accuracy_plot.append(1 - train_error)
            print('epoch {:.0f}, loss {:.4f}, train error {:.4f}'.format(e, train_loss, train_error))
            # TODO ##################################################
            # compute error on validation data:
            # simply make the function take validation data as input
            # and then compute errors here and print them
            # TODO ##################################################
            valid_loss = self._loss(X_valid, Y_valid_hot)
            valid_loss_plot.append(valid_loss)
            valid_error = self.classification_error(X_valid, Y_valid)
            valid_accuracy_plot.append(1 - valid_error)
            print('epoch {:.0f}, validation loss {:.4f}, validation error {:.4f}'.format(e, valid_loss, valid_error))
            #stop criterion
            if (self.loss_prev - valid_loss)**2 < eps:
                epochs = range(e+1)
                break
            else:
                self.loss_prev = valid_loss
            
        #Visualization of the error on train and validation data
        plt.plot(epochs, train_accuracy_plot, label="Training error", color='r')
        plt.plot(epochs, valid_accuracy_plot, label="Validation error", color='c')
        plt.plot(epochs, train_loss_plot, label="Train loss", color='g')
        plt.plot(epochs, valid_loss_plot, label="Validation loss", color='b')
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy/Loss")
        plt.legend(loc='best')
        plt.show()
            
    
    def check_gradients(self, X, Y):
        """ Helper function to test the parameter gradients for
        correctness. """
        for l, layer in enumerate(self.layers):
            if isinstance(layer, Parameterized):
                print('checking gradient for layer {}'.format(l))
                for p, param in enumerate(layer.params()):
                    # we iterate through all parameters
                    param_shape = param.shape
                    # define functions for conveniently swapping
                    # out parameters of this specific layer and 
                    # computing loss and gradient with these 
                    # changed parametrs
                    def output_given_params(param_new):
                        """ A function that will compute the output 
                            of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # return computed loss
                        return self._loss(X, Y)

                    def grad_given_params(param_new):
                        """A function that will compute the gradient 
                           of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # Forward propagation through the net
                        Y_pred = self.predict(X)
                        # Backpropagation of partial derivatives
                        self.backpropagate(Y, Y_pred, upto=l)
                        # return the computed gradient 
                        return np.ravel(self.layers[l].grad_params()[p])

                    # let the initial parameters be the ones that
                    # are currently placed in the network and flatten them
                    # to a vector for convenient comparisons, printing etc.
                    param_init = np.ravel(np.copy(param))
                    
                    # To debug you network's gradients use scipys
                    # gradient checking!
                    epsilon = 1e-5
                    import scipy.optimize
                    err = scipy.optimize.check_grad(output_given_params, 
                          grad_given_params, param_init) 
                    print('diff scipy {:.2e}'.format(err))
                    assert(err < epsilon)
                    
                    # reset the parameters to their initial values
                    param[:] = np.reshape(param_init, param_shape)

# %% [markdown]
# # Gradient Checking
# After implementing everything it is always a good idea to setup some layers and perform gradient
# checking on random data. **Note** that this is only an example! It is not a useful network architecture ;). We also expect you to play around with this to test all your implemented components.

# %%
input_shape = (5, 10)
n_labels = 6
layers = [InputLayer(input_shape)]

layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=15,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=6,
                init_stddev=0.1,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=n_labels,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(SoftmaxOutput(layers[-1]))
nn = NeuralNetwork(layers)

# %%
# create random data
X = np.random.normal(size=input_shape)
# and random labels
Y = np.zeros((input_shape[0], n_labels))
for i in range(Y.shape[0]):
    idx = np.random.randint(n_labels)
    Y[i, idx] = 1.

# %%
nn.check_gradients(X, Y)
# Out:
# checking gradient for layer 1
# diff scipy 2.21e-07
# diff scipy 5.05e-08
# checking gradient for layer 2
# diff scipy 1.64e-07
# diff scipy 4.73e-08
# checking gradient for layer 3
# diff scipy 8.16e-08
# diff scipy 2.57e-08

# %% [markdown]
# # Training on MNIST
# Finally we can let our network run on the MNIST dataset!

# %% [markdown]
# First load the data and reshape it.

# %%
# load
Dtrain, Dval, Dtest = mnist()
X_train, y_train = Dtrain
X_valid, y_valid = Dval
# Out:
# ... loading data
# ... done loading data

# %% [markdown]
# *Dtrain* contains 50k images which are of size 28 x 28 pixels. Hence:

# %%
print("X_train shape: {}".format(np.shape(X_train)))
print("y_train shape: {}".format(np.shape(y_train)))
# Out:
# X_train shape: (50000, 1, 28, 28)
# y_train shape: (50000,)

# %% [markdown]
# y_train will automatically be converted in the *train()* function to one_hot encoding.
#
#
# But we need to reshape X_train, as our Network expects flat vectors of size 28*28 as input!

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
print("Reshaped X_train size: {}".format(X_train.shape))
X_valid = X_valid.reshape((X_valid.shape[0], -1))
print("Reshaped X_valid size: {}".format(X_valid.shape))
# Out:
# Reshaped X_train size: (50000, 784)
# Reshaped X_valid size: (10000, 784)

# %% [markdown]
# Ah, much better ;-)!
#
# Now we can finally really start training a Network!
#
#
# I pre-defined a small Network for you below. Again This is not really a good default and will not produce state of the art results. Please play around with this a bit. See how different activation functions and training procedures (gd / sgd) affect the result.

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=100,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=100,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.1,
         max_epochs=20, batch_size=64, descent_type="sgd", y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# epoch 0, loss 2.2546, train error 0.5635
# epoch 0, validation loss 2.2539, validation error 0.5535
# epoch 1, loss 1.2105, train error 0.2997
# epoch 1, validation loss 1.1907, validation error 0.2805
# epoch 2, loss 0.6797, train error 0.1869
# epoch 2, validation loss 0.6454, validation error 0.1706
# epoch 3, loss 0.5329, train error 0.1511
# epoch 3, validation loss 0.4985, validation error 0.1370
# epoch 4, loss 0.4628, train error 0.1307
# epoch 4, validation loss 0.4296, validation error 0.1222
# epoch 5, loss 0.4231, train error 0.1198
# epoch 5, validation loss 0.3920, validation error 0.1131
# epoch 6, loss 0.3943, train error 0.1125
# epoch 6, validation loss 0.3634, validation error 0.1029
# epoch 7, loss 0.3729, train error 0.1063
# epoch 7, validation loss 0.3439, validation error 0.0980
# epoch 8, loss 0.3555, train error 0.1009
# epoch 8, validation loss 0.3274, validation error 0.0910
# epoch 9, loss 0.3403, train error 0.0967
# epoch 9, validation loss 0.3134, validation error 0.0868
# epoch 10, loss 0.3289, train error 0.0933
# epoch 10, validation loss 0.3033, validation error 0.0870
# epoch 11, loss 0.3176, train error 0.0906
# epoch 11, validation loss 0.2923, validation error 0.0832
# epoch 12, loss 0.3099, train error 0.0883
# epoch 12, validation loss 0.2849, validation error 0.0803
# epoch 13, loss 0.2998, train error 0.0854
# epoch 13, validation loss 0.2774, validation error 0.0793
# epoch 14, loss 0.2927, train error 0.0835
# epoch 14, validation loss 0.2709, validation error 0.0774
# epoch 15, loss 0.2867, train error 0.0824
# epoch 15, validation loss 0.2664, validation error 0.0755
# epoch 16, loss 0.2797, train error 0.0796
# epoch 16, validation loss 0.2605, validation error 0.0732
# epoch 17, loss 0.2749, train error 0.0787
# epoch 17, validation loss 0.2571, validation error 0.0729
# epoch 18, loss 0.2682, train error 0.0764
# epoch 18, validation loss 0.2514, validation error 0.0713
# epoch 19, loss 0.2634, train error 0.0753
# epoch 19, validation loss 0.2465, validation error 0.0705
# epoch 20, loss 0.2585, train error 0.0743
# epoch 20, validation loss 0.2429, validation error 0.0692
# Duration: 64.0s

# %% [markdown]
# # Figure out a reasonable Network that achieves good performance
# As the last part of this task, setup a network that works well and gets reasonable accuracy, say ~ 1-3 percent error on the **validation set**.
# Train this network on the complete data and compute the **test error**.
#
# Visualize the validation loss and training loss for each iteration in a plot, e.g. using matplotlib

# %%
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=800,
                init_stddev=0.01,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=400,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.5, 
         max_epochs=100, batch_size=64, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# epoch 0, loss 0.3198, train error 0.0912
# epoch 0, validation loss 0.2970, validation error 0.0860
# epoch 1, loss 0.2480, train error 0.0727
# epoch 1, validation loss 0.2323, validation error 0.0676
# epoch 2, loss 0.2028, train error 0.0592
# epoch 2, validation loss 0.1938, validation error 0.0555
# epoch 3, loss 0.1788, train error 0.0525
# epoch 3, validation loss 0.1747, validation error 0.0475
# epoch 4, loss 0.1524, train error 0.0440
# epoch 4, validation loss 0.1538, validation error 0.0436
# epoch 5, loss 0.1314, train error 0.0376
# epoch 5, validation loss 0.1376, validation error 0.0392
# epoch 6, loss 0.1178, train error 0.0340
# epoch 6, validation loss 0.1256, validation error 0.0357
# epoch 7, loss 0.1058, train error 0.0303
# epoch 7, validation loss 0.1175, validation error 0.0331
# epoch 8, loss 0.0960, train error 0.0275
# epoch 8, validation loss 0.1097, validation error 0.0303
# epoch 9, loss 0.0878, train error 0.0249
# epoch 9, validation loss 0.1038, validation error 0.0295
# epoch 10, loss 0.0790, train error 0.0222
# epoch 10, validation loss 0.0976, validation error 0.0281
# epoch 11, loss 0.0741, train error 0.0199
# epoch 11, validation loss 0.0952, validation error 0.0281
# epoch 12, loss 0.0695, train error 0.0190
# epoch 12, validation loss 0.0935, validation error 0.0270
# epoch 13, loss 0.0630, train error 0.0169
# epoch 13, validation loss 0.0894, validation error 0.0264
# epoch 14, loss 0.0574, train error 0.0152
# epoch 14, validation loss 0.0844, validation error 0.0257
# epoch 15, loss 0.0542, train error 0.0139
# epoch 15, validation loss 0.0838, validation error 0.0244
# epoch 16, loss 0.0499, train error 0.0125
# epoch 16, validation loss 0.0820, validation error 0.0242
# epoch 17, loss 0.0464, train error 0.0115
# epoch 17, validation loss 0.0785, validation error 0.0236
# epoch 18, loss 0.0429, train error 0.0103
# epoch 18, validation loss 0.0772, validation error 0.0226
# epoch 19, loss 0.0402, train error 0.0093
# epoch 19, validation loss 0.0758, validation error 0.0220
# epoch 20, loss 0.0367, train error 0.0087
# epoch 20, validation loss 0.0740, validation error 0.0217
# epoch 21, loss 0.0344, train error 0.0074
# epoch 21, validation loss 0.0725, validation error 0.0213
# epoch 22, loss 0.0324, train error 0.0069
# epoch 22, validation loss 0.0720, validation error 0.0210
# epoch 23, loss 0.0314, train error 0.0065
# epoch 23, validation loss 0.0720, validation error 0.0213
# epoch 24, loss 0.0281, train error 0.0056
# epoch 24, validation loss 0.0691, validation error 0.0206
# epoch 25, loss 0.0268, train error 0.0051
# epoch 25, validation loss 0.0686, validation error 0.0205
# epoch 26, loss 0.0252, train error 0.0048
# epoch 26, validation loss 0.0682, validation error 0.0194
# epoch 27, loss 0.0241, train error 0.0044
# epoch 27, validation loss 0.0670, validation error 0.0199
# epoch 28, loss 0.0225, train error 0.0039
# epoch 28, validation loss 0.0661, validation error 0.0193
# epoch 29, loss 0.0208, train error 0.0032
# epoch 29, validation loss 0.0661, validation error 0.0204
# epoch 30, loss 0.0200, train error 0.0029
# epoch 30, validation loss 0.0654, validation error 0.0201
# epoch 31, loss 0.0189, train error 0.0028
# epoch 31, validation loss 0.0660, validation error 0.0196
# epoch 32, loss 0.0178, train error 0.0024
# epoch 32, validation loss 0.0646, validation error 0.0191
# epoch 33, loss 0.0173, train error 0.0025
# epoch 33, validation loss 0.0649, validation error 0.0198
# epoch 34, loss 0.0163, train error 0.0020
# epoch 34, validation loss 0.0640, validation error 0.0200
# epoch 35, loss 0.0152, train error 0.0016
# epoch 35, validation loss 0.0633, validation error 0.0200
# epoch 36, loss 0.0146, train error 0.0016
# epoch 36, validation loss 0.0635, validation error 0.0200
# epoch 37, loss 0.0151, train error 0.0017
# epoch 37, validation loss 0.0646, validation error 0.0207
# epoch 38, loss 0.0134, train error 0.0015
# epoch 38, validation loss 0.0630, validation error 0.0194
# epoch 39, loss 0.0129, train error 0.0013
# epoch 39, validation loss 0.0642, validation error 0.0189
# epoch 40, loss 0.0123, train error 0.0012
# epoch 40, validation loss 0.0629, validation error 0.0188
# epoch 41, loss 0.0116, train error 0.0010
# epoch 41, validation loss 0.0633, validation error 0.0193
# epoch 42, loss 0.0112, train error 0.0010
# epoch 42, validation loss 0.0627, validation error 0.0197
# epoch 43, loss 0.0105, train error 0.0009
# epoch 43, validation loss 0.0622, validation error 0.0186
# epoch 44, loss 0.0101, train error 0.0008
# epoch 44, validation loss 0.0623, validation error 0.0188
# epoch 45, loss 0.0097, train error 0.0006
# epoch 45, validation loss 0.0619, validation error 0.0186
# epoch 46, loss 0.0094, train error 0.0007
# epoch 46, validation loss 0.0627, validation error 0.0191
# epoch 47, loss 0.0089, train error 0.0006
# epoch 47, validation loss 0.0617, validation error 0.0185
# epoch 48, loss 0.0086, train error 0.0005
# epoch 48, validation loss 0.0626, validation error 0.0187
# epoch 49, loss 0.0082, train error 0.0004
# epoch 49, validation loss 0.0619, validation error 0.0181
# epoch 50, loss 0.0079, train error 0.0004
# epoch 50, validation loss 0.0621, validation error 0.0192
# epoch 51, loss 0.0076, train error 0.0004
# epoch 51, validation loss 0.0619, validation error 0.0186
# epoch 52, loss 0.0075, train error 0.0004
# epoch 52, validation loss 0.0625, validation error 0.0189
# epoch 53, loss 0.0073, train error 0.0005
# epoch 53, validation loss 0.0624, validation error 0.0180
# epoch 54, loss 0.0068, train error 0.0002
# epoch 54, validation loss 0.0621, validation error 0.0188
# epoch 55, loss 0.0066, train error 0.0003
# epoch 55, validation loss 0.0613, validation error 0.0181
# epoch 56, loss 0.0065, train error 0.0002
# epoch 56, validation loss 0.0614, validation error 0.0180
# epoch 57, loss 0.0062, train error 0.0001
# epoch 57, validation loss 0.0612, validation error 0.0178
# epoch 58, loss 0.0061, train error 0.0002
# epoch 58, validation loss 0.0612, validation error 0.0175
# epoch 59, loss 0.0059, train error 0.0002
# epoch 59, validation loss 0.0613, validation error 0.0184
# epoch 60, loss 0.0057, train error 0.0002
# epoch 60, validation loss 0.0614, validation error 0.0179
# epoch 61, loss 0.0055, train error 0.0002
# epoch 61, validation loss 0.0618, validation error 0.0181
# epoch 62, loss 0.0053, train error 0.0001
# epoch 62, validation loss 0.0622, validation error 0.0180
# epoch 63, loss 0.0052, train error 0.0001
# epoch 63, validation loss 0.0618, validation error 0.0182
# epoch 64, loss 0.0051, train error 0.0002
# epoch 64, validation loss 0.0615, validation error 0.0180
# epoch 65, loss 0.0049, train error 0.0002
# epoch 65, validation loss 0.0616, validation error 0.0177
# epoch 66, loss 0.0048, train error 0.0001
# epoch 66, validation loss 0.0620, validation error 0.0183
# epoch 67, loss 0.0047, train error 0.0001
# epoch 67, validation loss 0.0620, validation error 0.0183
# epoch 68, loss 0.0045, train error 0.0001
# epoch 68, validation loss 0.0619, validation error 0.0178
# epoch 69, loss 0.0044, train error 0.0000
# epoch 69, validation loss 0.0614, validation error 0.0173
# epoch 70, loss 0.0043, train error 0.0000
# epoch 70, validation loss 0.0619, validation error 0.0176
# epoch 71, loss 0.0042, train error 0.0001
# epoch 71, validation loss 0.0617, validation error 0.0179
# epoch 72, loss 0.0041, train error 0.0000
# epoch 72, validation loss 0.0621, validation error 0.0182
# epoch 73, loss 0.0040, train error 0.0000
# epoch 73, validation loss 0.0616, validation error 0.0176
# epoch 74, loss 0.0039, train error 0.0000
# epoch 74, validation loss 0.0615, validation error 0.0172
# epoch 75, loss 0.0038, train error 0.0000
# epoch 75, validation loss 0.0619, validation error 0.0180
# epoch 76, loss 0.0037, train error 0.0000
# epoch 76, validation loss 0.0625, validation error 0.0177
# epoch 77, loss 0.0037, train error 0.0000
# epoch 77, validation loss 0.0625, validation error 0.0181
# epoch 78, loss 0.0036, train error 0.0000
# epoch 78, validation loss 0.0623, validation error 0.0180
# epoch 79, loss 0.0035, train error 0.0000
# epoch 79, validation loss 0.0626, validation error 0.0178
# epoch 80, loss 0.0034, train error 0.0000
# epoch 80, validation loss 0.0628, validation error 0.0182
# epoch 81, loss 0.0034, train error 0.0000
# epoch 81, validation loss 0.0627, validation error 0.0178
# epoch 82, loss 0.0033, train error 0.0000
# epoch 82, validation loss 0.0622, validation error 0.0177
# epoch 83, loss 0.0032, train error 0.0000
# epoch 83, validation loss 0.0625, validation error 0.0180
# epoch 84, loss 0.0032, train error 0.0000
# epoch 84, validation loss 0.0622, validation error 0.0181
# epoch 85, loss 0.0031, train error 0.0000
# epoch 85, validation loss 0.0620, validation error 0.0178
# epoch 86, loss 0.0031, train error 0.0000
# epoch 86, validation loss 0.0622, validation error 0.0176
# epoch 87, loss 0.0030, train error 0.0000
# epoch 87, validation loss 0.0624, validation error 0.0182
# epoch 88, loss 0.0029, train error 0.0000
# epoch 88, validation loss 0.0623, validation error 0.0175
# epoch 89, loss 0.0029, train error 0.0000
# epoch 89, validation loss 0.0623, validation error 0.0175
# epoch 90, loss 0.0028, train error 0.0000
# epoch 90, validation loss 0.0623, validation error 0.0177
# epoch 91, loss 0.0028, train error 0.0000
# epoch 91, validation loss 0.0629, validation error 0.0176
# epoch 92, loss 0.0027, train error 0.0000
# epoch 92, validation loss 0.0630, validation error 0.0177
# epoch 93, loss 0.0027, train error 0.0000
# epoch 93, validation loss 0.0627, validation error 0.0177
# epoch 94, loss 0.0026, train error 0.0000
# epoch 94, validation loss 0.0622, validation error 0.0174
# epoch 95, loss 0.0026, train error 0.0000
# epoch 95, validation loss 0.0625, validation error 0.0176
# epoch 96, loss 0.0025, train error 0.0000
# epoch 96, validation loss 0.0624, validation error 0.0173
# epoch 97, loss 0.0025, train error 0.0000
# epoch 97, validation loss 0.0621, validation error 0.0173
# epoch 98, loss 0.0025, train error 0.0000
# epoch 98, validation loss 0.0624, validation error 0.0176
# epoch 99, loss 0.0024, train error 0.0000
# epoch 99, validation loss 0.0629, validation error 0.0176
# epoch 100, loss 0.0024, train error 0.0000
# epoch 100, validation loss 0.0625, validation error 0.0179
# Duration: 3432.3s

# %%
#test network
X_test, y_test = Dtest
X_test = X_test.reshape(X_test.shape[0], -1)
test_error = nn.classification_error(X_test, y_test)
print('test error {:.4f}'.format(test_error))
# Out:
# test error 0.0169
